# %% [markdown]
# # Classes

# %% [markdown]
# ## Enseignant

# %%
import os
import math
import glob
import re
import operator
import time
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class Enseignant:
    def __init__(self, nom, prenom, statut):
        self.nom = nom
        self.prenom=prenom
        self.telephone="nil"
        self.mail_ujm="nil"
        self.mail_perso="nil"
        self.adresse="nil"
        self.statut=statut
        self.cours=[]
        self.charge=[]
        self.service=0

class Niveau: 
    def __init__(self, niveau):
        self.niveau = niveau
        
class Enseignement:
    def __init__(self, niveau, semestre, code, titre, groupes):
        self.niveau = niveau
        self.semestre = semestre
        self.code = code
        self.titre = titre
        self.htd = 0
        self.hcm = 0
        self.groupes = groupes
        self.cours = []
                
class Charge_admin:
    def __init__(self, titre, htd):
        self.titre = titre
        self.htd = htd
        self.rqs = "nil"
        
class Cours:
    def __init__(self, enseignant, enseignement):
        self.enseignant = enseignant
        self.enseignement = enseignement
        self.duree = 0
        self.nseances = 0
        self.groupes = 0
        self.dates = []
        self.hdebut = 0
        self.jour = "nil"
        self.type = "TD"
        self.salle = "nil"
        self.groupe = "nil"
        self.rqs = "nil"
        
class Salle:
    def __init__ (self, site, code):
        self.site = site
        self.code = code
    def __lt__ (self, other):
        return self.site < other.site
    
class Annee:
    def __init__ (self, annee, semestre1, semestre2, admin):
        self.annee = annee
        self.semestre1 = semestre1
        self.semestre2 = semestre2
        self.admin = admin
    
class Semestre:
    def __init__ (self, cours):
        self.cours = cours

# %%
os.chdir("/Users/laurentpottier/Documents/LP/Recherches/Dir_Departement/Python_Planning/files/")

# %%
X = pd.read_excel("Services_enseignants2021-22q.xlsx",sheet_name=0,header=0,index_col=0)

# %%
print(X.shape) # (18, 6)
print (X.index[3])
print (X.columns[2])
print (X.nom[2])
print (X.niveau[2])
print (X.site[2])
print (X.salle[2])
print (type(X.rqs[2]))
heure1 = X.début[2]
print (heure1)
print (heure1.hour)
print (heure1.minute)
print (type (heure1))
print (type (5))
#print (type (08:00:00))
#HOUR = timedelta(hours=1)
#print (dir(HOUR))
#print (type (HOUR))
#print (dir(heure1))
print (heure1.minute)
print ("heure1, datetime.time :" , isinstance (heure1, datetime.time))
# Out:
# (186, 21)
# 4
# heures
# Pottier
# L
# Papin
# A230
# <class 'float'>
# 08:30:00
# 8
# 30
# <class 'datetime.time'>
# <class 'int'>
# 30
# heure1, datetime.time : True

# %%
#print (Enseignants)
#print (Enseignants[0].nom)
#print (len(Enseignants))

def noms_enseignants(ListeEnseignants):
    res = []
    for i in range (len(ListeEnseignants)):
        res.append (ListeEnseignants[i].nom)
    return res

def prenoms_enseignants(ListeEnseignants):
    res = []
    for i in range (len(ListeEnseignants)):
        res.append (ListeEnseignants[i].prenom)
    return res

# %%
def add_cours_enseignant(enseignants, base, j):
    """dsflkjsldfkj"""
    nom_enseignant = base.nom[j]
    #si un enseignant est référencé dans la ligne considérée
    if (not (isinstance(nom_enseignant, (int, float)))): 
        print (nom_enseignant)
        # si l'enseignant n'est pas dans la base on l'ajoute
        if nom_enseignant not in (noms_enseignants (enseignants)):
            enseignant = Enseignant(nom_enseignant, base.prenom[j], base.statut[j])   
            Enseignants.append(enseignant)

        liste_enseignants = noms_enseignants(Enseignants)
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = enseignants[nth]
        niveau = base.niveau[j]
        if (not (isinstance(niveau, (int, float)))): 
            enseignement = Enseignement(niveau, base.semestre[j], base.code[j], base.titre[j],base.groupes[j]) 
            cours = Cours(enseignant, enseignement)
            cours.duree = base.duree[j]
            if (isinstance (base.début[j], datetime.time)):
                cours.hdebut = base.début[j]
            cours.jour = base.jour[j]
            base.etudts[j]
            cours.groupes = base.groupes[j]
            cours.rqs = base.rqs[j]
            if(base.TD_CM[j]==1):
                cours.type = "TD" 
            elif(base.TD_CM[j]==1.5):
                cours.type = "CM" 
            else:
                cours.type = "nil"
            cours.salle = base.salle[j]
            cours.nseances = base.nseances[j]
            #print (liste_enseignants)
            enseignant.cours.append(cours)
        else:
            charge = Charge_admin(base.titre[j],base.duree[j])
            charge.rqs = base.rqs[j]
            enseignant.charge.append(charge)

    
#add_cours_enseignant(Enseignants, X, 144)

# %%
# => X est la base issue d'Excel
# => Enseignants est la base créée à partir de X, liste d'enseignants (de la classe Enseignant)
Enseignants = []

def readlines (base, LEnseignants):
    for j in range(base.shape[0]):
        #print (j)
        add_cours_enseignant(LEnseignants, base, 1+j)
        
readlines (X, Enseignants)
# Out:
# Pottier
# Olivo
# Olivo
# Obali
# Obali
# Clerc
# Clerc
# Fargeton
# Lapalu
# Fargeton
# Houles
# Fargeton
# Fargeton
# Houles
# Houles
# Y
# Bertrand
# Petiet
# Houles
# Houles
# Damon-Guillot
# X
# Bertrand
# Houles
# Obali
# Clerc
# Clerc
# Damon-Guillot
# Lapalu
# Cailliez
# Houles
# Fargeton
# Fargeton
# Rascle
# Y
# Houles
# Houles
# Y
# Houles
# Houles
# Bertrand
# Petiet
# Houles
# Houles
# Cailliez
# Bertrand
# Desmet
# Tracy
# Houles
# Damon-Guillot
# Houles
# Houles
# Bertrand
# Viallon
# Fuchs
# Fuchs
# Fargeton
# Fargeton
# Forment
# Houles
# Cailliez
# Cailliez
# Tracy
# Houles
# Damon-Guillot
# Houles
# Houles
# Bertrand
# Viallon
# Fuchs
# Fargeton
# Damon-Guillot
# Forment
# Houles
# Desmet
# Desmet
# Fargeton
# Pottier
# Pottier
# Cailliez
# Bardot
# Terras
# Viallon
# Garde
# Garde
# Houles
# Fuchs
# Fuchs
# Clerc
# Desmet
# Desmet
# Damon-Guillot
# Delaigue
# Pottier
# Pottier
# Waschbüsch
# Jakubowski
# Jakubowski
# Terras
# Viallon
# Garde
# Houles
# Fuchs
# Clerc
# Desmet
# Rascle
# Damon-Guillot
# Moussart
# Desmet
# Pottier
# Waschbüsch
# Damon-Guillot
# Damon-Guillot
# Houles
# Houles
# Aliot
# Carinola
# Carinola
# Cailliez
# Cailliez
# Cailliez
# Damon-Guillot
# Damon-Guillot
# Damon-Guillot
# Pottier
# Pottier
# Pottier
# Jacquelot
# Michon
# Michon
# Moussart
# Desmet
# Desmet
# Fargeton
# Fargeton
# Waschbüsch
# Waschbüsch
# Jouve Villard
# Nosella
# Dalem
# Ezequel
# Ezequel
# Desmet
# Waschbüsch
# Waschbüsch
# Pottier
# Pottier
# Pottier
# Desmet
# Fargeton
# Pottier
# Fargeton
# Pottier
# Pottier
# Pottier
# Pottier
# Damon-Guillot
# Desmet
# Waschbüsch
# Cailliez
# Waschbüsch
# Waschbüsch

# %%
print("heure :" , str(Enseignants[1].cours[1].hdebut.hour)+"h"+str(Enseignants[1].cours[1].hdebut.minute))
# Out:
# heure : 14h45

# %%
def service(LEnseignants, nom_enseignant):    
    liste_enseignants = noms_enseignants(LEnseignants)
    nth = liste_enseignants.index(nom_enseignant)
    enseignant = LEnseignants[nth]
    cours = enseignant.cours
    charge = enseignant.charge
    service = 0
    print("service de ", enseignant.prenom,  nom_enseignant, ":")
    for j in range(len(cours)):
        duree = cours[j].duree
        nseances = cours[j].nseances
        groupes = cours[j].groupes
        enseignement = cours[j].enseignement
        niveau = enseignement.niveau
        semestre = int(enseignement.semestre)
        code = enseignement.code
        if (isinstance(code, (int, float))):
            code = "Gal"            
        titre = enseignement.titre
        TD_CM = coefTDCM(cours[j].type)
        hetd = duree * nseances * groupes * TD_CM
        print(niveau, "S"+str(semestre), code, titre, " : " ,hetd, "hetd")
        service += hetd
    for j in range(len(charge)):
        hetd = charge[j].htd
        titre = charge[j].titre
        print(titre, " : " ,hetd, "hetd")
        service += hetd
    print ("total :", service, "hetd")
    return service

def coefTDCM(typ):
    if(typ=="TD"):
        coef = 1
    elif(typ=="CM"):
        coef = 1.5 
    else:
        coef = 0 
    return coef
                
service(Enseignants, "Damon-Guillot")
# Out:
# service de  Anne Damon-Guillot :
# L S1 UE6-B Solfege initiant  :  8.0 hetd
# L S2 UE3-A Arts et spe-ethno  :  27.0 hetd
# L S3 UE1-D PPP  :  11.0 hetd
# L S4 UE1-D PPP  :  0.0 hetd
# L S4 UE3-A Ethnomusicologie  :  36.0 hetd
# L S6 UE1-A Ethnomusicologie  :  30.0 hetd
# L S6 Gal Enseignant référent  :  12.0 hetd
# M S1 UE1-2 Methodologie  :  2.5 hetd
# M S1 UE1-2 Methodologie  :  4.0 hetd
# M S1 UE2-A2 Ethnomusicologie  :  4.5 hetd
# M S1 UE2-A2 Ethnomusicologie  :  18.0 hetd
# M S1 UE2-A2 Ethnomusicologie  :  6.0 hetd
# Co-direction A.R.T.S.  :  36.0 hetd
# total : 195.0 hetd
# 195.0

# %%
liste_enseignants = noms_enseignants(Enseignants)
#print (liste_enseignants)
#print (liste_enseignants.index('Pottier'))
#cours1 = (Enseignants[2].cours)
#print (len(cours1))
#print ("durée :" , cours1[1].duree)

def services(LEnseignants):
    liste_enseignants = noms_enseignants(Enseignants)
    liste_enseignants_tri = sorted(noms_enseignants(Enseignants))
    # les enseignants Musique
    for i in range (len(liste_enseignants)):
        nom_enseignant = liste_enseignants_tri[i]
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        #print (enseignant.statut)
        #service(Enseignants, liste_enseignants_tri[i])
        if (not (isinstance(enseignant.statut, (int, float)))):
            if ("Musique" in enseignant.statut):
                service(Enseignants, liste_enseignants_tri[i])
   # les autres enseignants
    for i in range (len(liste_enseignants)):
        nom_enseignant = liste_enseignants_tri[i]
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        #service(Enseignants, liste_enseignants_tri[i])
        if (not (isinstance(enseignant.statut, (int, float)))):
            if (not "Musique" in enseignant.statut):
                service(Enseignants, liste_enseignants_tri[i])
        
services(Enseignants)
# Out:
# service de  Matthieu Cailliez :
# L S2 UE4 Histoire XVIIIe  :  36.0 hetd
# L S2 UE6-C Solfege initiant  :  24.0 hetd
# L S3 UE3-D Histoire de la musique 1800-70  :  27.0 hetd
# L S3 UE3-D Histoire de la musique 1800-70  :  27.0 hetd
# L S5 UE1-C Histoire de la musique 1870-1930  :  36.0 hetd
# M S1 UE2-A1 Musicologie XVIII-XIXe  :  4.5 hetd
# M S1 UE2-A1 Musicologie XVIII-XIXe  :  18.0 hetd
# M S1 UE2-A1 Musicologie XVIII-XIXe  :  6.0 hetd
# Formation nouveaux recrutés  :  33.0 hetd
# total : 211.5 hetd
# service de  Anne Damon-Guillot :
# L S1 UE6-B Solfege initiant  :  8.0 hetd
# L S2 UE3-A Arts et spe-ethno  :  27.0 hetd
# L S3 UE1-D PPP  :  11.0 hetd
# L S4 UE1-D PPP  :  0.0 hetd
# L S4 UE3-A Ethnomusicologie  :  36.0 hetd
# L S6 UE1-A Ethnomusicologie  :  30.0 hetd
# L S6 Gal Enseignant référent  :  12.0 hetd
# M S1 UE1-2 Methodologie  :  2.5 hetd
# M S1 UE1-2 Methodologie  :  4.0 hetd
# M S1 UE2-A2 Ethnomusicologie  :  4.5 hetd
# M S1 UE2-A2 Ethnomusicologie  :  18.0 hetd
# M S1 UE2-A2 Ethnomusicologie  :  6.0 hetd
# Co-direction A.R.T.S.  :  36.0 hetd
# total : 195.0 hetd
# service de  Marc Desmet :
# L S2 Gal Enseignant référent  :  18.0 hetd
# L S4 UE3-D Histoire de la musique 900-1600  :  27.0 hetd
# L S4 UE3-D Histoire de la musique 900-1600  :  27.0 hetd
# L S5 UE3-B1 Paléographie musicale 1  :  18.0 hetd
# L S5 UE3-B2 Iconographie musicale  :  18.0 hetd
# L S6 UE3-B1 Paléographie musicale 1  :  18.0 hetd
# M S1 UE1-2 Methodologie  :  10.0 hetd
# M S2 UE2-A1 Musicologie XVIe-XVIIe  :  22.5 hetd
# M S2 UE2-A1 Musicologie XVIe-XVIIe  :  6.0 hetd
# AGM S4 UE4-1 Recherche en discographie  :  12.0 hetd
# ALL S2 Gal Dialogue des Arts  :  1.5 hetd
# Mission R.I.  :  24.0 hetd
# total : 202.0 hetd
# service de  Pierre Fargeton :
# L S1 UE3-A Arts et spe-jazz  :  27.0 hetd
# L S1 UE4 Histoire des arts  :  36.0 hetd
# L S1 UE5-B Musique d'ensemble  :  15.0 hetd
# L S1 UE5-B Musique d'ensemble  :  15.0 hetd
# L S2 UE5-B Musique d'ensemble  :  15.0 hetd
# L S2 UE5-B Musique d'ensemble  :  15.0 hetd
# L S3 UE2-D Musique d'ensemble  :  24.0 hetd
# L S3 UE3-A Jazz  :  36.0 hetd
# L S4 UE2-D Musique d'ensemble  :  24.0 hetd
# L S5 UE1-A Jazz  :  36.0 hetd
# M S2 UE2-A2 Jazz  :  22.5 hetd
# M S2 UE2-A2 Jazz  :  6.0 hetd
# ALL S2 Gal Dialogue des Arts  :  1.5 hetd
# Comedie S1 Gal Musicologie pour comédiens  :  9.0 hetd
# total : 282.0 hetd
# service de  Fabien Houles :
# L S1 UE5-A Chorale  :  36.0 hetd
# L S1 UE6-A Technique analyse auditive  :  18.0 hetd
# L S1 UE6-A Technique analyse auditive  :  18.0 hetd
# L S1 UE6-B Solfege (dechiffrage chanté)  :  6.0 hetd
# L S1 UE6-B Solfege (dechiffrage chanté)  :  6.0 hetd
# L S2 UE1 Methodologie  :  18.0 hetd
# L S2 UE5-A Chorale  :  36.0 hetd
# L S2 UE6-A Technique analyse partition  :  18.0 hetd
# L S2 UE6-A Technique analyse partition  :  18.0 hetd
# L S2 UE6-B Harmonie  :  24.0 hetd
# L S2 UE6-B Harmonie  :  24.0 hetd
# L S2 UE6-C Solfege (dechiffrage chanté)  :  6.0 hetd
# L S2 UE6-C Solfege (dechiffrage chanté)  :  6.0 hetd
# L S3 UE1-B Chorale  :  0.0 hetd
# L S3 UE2-A Harmonie  :  24.0 hetd
# L S3 UE2-A Harmonie  :  24.0 hetd
# L S3 UE3-C Analyse sur partitions  :  27.0 hetd
# L S4 UE1-B Chorale  :  0.0 hetd
# L S4 UE2-A Harmonie  :  24.0 hetd
# L S4 UE2-A Harmonie  :  24.0 hetd
# L S4 UE3-C Analyse auditive  :  27.0 hetd
# L S5 UE2-D Direction de choeur  :  24.0 hetd
# L S6 UE2-D Direction de choeur  :  24.0 hetd
# M S1 UE1-4a Analyse auditive  :  9.0 hetd
# M S1 UE1-4a Analyse auditive  :  6.0 hetd
# total : 447.0 hetd
# service de  Matteo Olivo :
# L S1 UE1-B Methodologie  :  18.0 hetd
# L S1 UE1-B Methodologie  :  18.0 hetd
# total : 36.0 hetd
# service de  Laurent Pottier :
# L S1 UE1-A TICE  :  24.0 hetd
# L S5 UE1-B Acoustique  :  13.5 hetd
# L S5 UE1-B Acoustique  :  12.0 hetd
# L S6 UE1-B Histoire des musiques électroac  :  13.5 hetd
# L S6 UE1-B Histoire des musiques électroac  :  12.0 hetd
# M S1 UE1-2 Methodologie  :  6.0 hetd
# M S1 UE2-A3 Musique électroacoustiques  :  4.5 hetd
# M S1 UE2-A3 Musique électroacoustiques  :  18.0 hetd
# M S1 UE2-A3 Musique électroacoustiques  :  6.0 hetd
# RIM S3 UE3-B Composition algorithmique  :  12.0 hetd
# RIM S3 UE3-C Dispo. audio temps réel  :  10.0 hetd
# RIM S3 Gal Projets  :  4.0 hetd
# ALL S2 Gal Dialogue des Arts  :  1.5 hetd
# Artnum S1 Gal Histoire arts nums  :  2.0 hetd
# Direction département musique  :  28.0 hetd
# Direction RIM  :  20.0 hetd
# Référent Pédagogie Numérique  :  20.0 hetd
# total : 207.0 hetd
# service de  Viviane Waschbüsch :
# L S6 UE1-C Histoire de la musique après 1930  :  36.0 hetd
# M S1 UE1-2 Methodologie  :  1.5 hetd
# M S2 UE2-A3 Musicologie XXe-XXIe  :  22.5 hetd
# M S2 UE2-A3 Musicologie XXe-XXIe  :  6.0 hetd
# AGM S3 Gal Projet coll  :  10.0 hetd
# AGM S3 Gal Projet perso  :  9.0 hetd
# Direction AGM  :  30.0 hetd
# Formation nouveaux recrutés  :  33.0 hetd
# Décharge jeune chercheuse  :  44.0 hetd
# total : 192.0 hetd
# service de  X X :
# L S1 UE6-B Solfege initiant  :  16.0 hetd
# total : 16.0 hetd
# service de  Greg Aliot :
# M S1 UE1-4b Techniques de studio  :  20.0 hetd
# total : 20.0 hetd
# service de  Jean-Marc Bardot :
# L S5 UE1-C Histoire de la musique 1870-1930  :  36.0 hetd
# total : 36.0 hetd
# service de  Valérie Bertrand :
# L S1 UE6-B Solfege  :  24.0 hetd
# L S1 UE6-B Solfege initiant  :  24.0 hetd
# L S2 UE6-C Solfege  :  24.0 hetd
# L S2 UE6-C Solfege initiant  :  24.0 hetd
# L S3 UE2-B Solfege  :  24.0 hetd
# L S4 UE2-B Solfege  :  24.0 hetd
# total : 144.0 hetd
# service de  Vincent Carinola :
# M S1 UE1-4b Techniques de studio  :  6.0 hetd
# M S1 UE1-4b Techniques de studio  :  4.0 hetd
# total : 10.0 hetd
# service de  Leo Clerc :
# L S1 UE2-B Anglais  :  18.0 hetd
# L S1 UE2-B Anglais  :  18.0 hetd
# L S2 UE2-B Anglais  :  18.0 hetd
# L S2 UE2-B Anglais  :  18.0 hetd
# L S5 UE3-A Anglais  :  18.0 hetd
# L S6 UE3-A Anglais  :  18.0 hetd
# total : 108.0 hetd
# service de  Nicolas Delaigue :
# L S6 UE1-A Ethnomusicologie  :  6.0 hetd
# total : 6.0 hetd
# service de  Philippe Ezequel :
# M S2 UE2-B5 Initiation à la programmation  :  18.0 hetd
# M S2 UE2-B5 Initiation à la programmation  :  12.0 hetd
# total : 30.0 hetd
# service de  Raphael Forment :
# L S3 UE3-B Atelier d'informatique mus  :  24.0 hetd
# L S4 UE3-B Atelier d'informatique mus  :  24.0 hetd
# total : 48.0 hetd
# service de  Catherine Fuchs :
# L S3 UE2-C Accompagnement  :  10.0 hetd
# L S3 UE2-C Accompagnement  :  10.0 hetd
# L S4 UE2-C Accompagnement  :  20.0 hetd
# L S5 UE2-E Accompagnement  :  12.0 hetd
# L S5 UE2-E Accompagnement  :  12.0 hetd
# L S6 UE2-E Accompagnement  :  24.0 hetd
# total : 88.0 hetd
# service de  Cédric Garde :
# L S5 UE2-C Pratique vocale individuelle  :  36.0 hetd
# L S5 UE2-C Pratique vocale individuelle  :  36.0 hetd
# L S5 UE2-C Pratique vocale individuelle  :  24.0 hetd
# total : 96.0 hetd
# service de  Pascale Jakubowski :
# L S6 UE1-C Histoire de la musique après 1930  :  30.0 hetd
# L S6 UE1-C Histoire de la musique après 1930  :  6.0 hetd
# total : 36.0 hetd
# service de  Laure Jouve Villard :
# M S2 UE2-B3 Mediation culturelle  :  nan hetd
# total : nan hetd
# service de  Claire Lapalu :
# L S1 UE3-B Esthétique  :  27.0 hetd
# L S2 UE3-B Esthétique  :  27.0 hetd
# total : 54.0 hetd
# service de  Romain Michon :
# M S1 UE2-B5 Atelier d'informatique musicale  :  9.0 hetd
# M S1 UE2-B5 Atelier d'informatique musicale  :  6.0 hetd
# total : 15.0 hetd
# service de  Arnaud Moussart :
# M S1 UE1-1 Anglais  :  18.0 hetd
# M S2 UE1-1 Anglais  :  18.0 hetd
# total : 36.0 hetd
# service de  Carole Nosella :
# M S2 UE2-B4 Espaces et réseaux  :  nan hetd
# total : nan hetd
# service de  M. Obali :
# L S1 UE2-A Français  :  18.0 hetd
# L S1 UE2-A Français  :  18.0 hetd
# L S2 UE2-A Français  :  18.0 hetd
# total : 54.0 hetd
# service de  Victor Petiet :
# L S1 UE6-B Solfege  :  24.0 hetd
# L S2 UE6-C Solfege  :  24.0 hetd
# total : 48.0 hetd
# service de  Lionel Rascle :
# L S2 UE5-C Atelier info mus  :  24.0 hetd
# L S6 UE3-B2 Musique et image  :  18.0 hetd
# total : 42.0 hetd
# service de  Bastien Terras :
# L S5 UE2-A Harmonie  :  48.0 hetd
# L S6 UE2-A Harmonie  :  48.0 hetd
# total : 96.0 hetd
# service de  Leland Tracy :
# L S3 UE1-A Anglais  :  18.0 hetd
# L S4 UE1-A Anglais  :  18.0 hetd
# total : 36.0 hetd
# service de  Agnès Viallon :
# L S3 UE2-B Solfege  :  24.0 hetd
# L S4 UE2-B Solfege  :  24.0 hetd
# L S5 UE2-B Solfège  :  48.0 hetd
# L S6 UE2-B Solfège  :  48.0 hetd
# total : 144.0 hetd
# service de  etudiant Y :
# L S1 UE6-A Technique analyse auditive  :  12.0 hetd
# L S2 UE5-C Atelier info mus  :  24.0 hetd
# L S2 UE6-A Technique analyse partition  :  12.0 hetd
# total : 48.0 hetd

# %%
a = "UJM-MCF-Musique"

"Musique" in a
# Out:
# True

# %%
#with open("coco", "w") as filout:
#    s = "service de " +  "lp" +  "\n" + "nom_enseignant" + ": " + str(5.2)
#    filout.write(s)

# %%
def service_print(LEnseignants, nom_enseignant, filout):
        liste_enseignants = noms_enseignants(LEnseignants)
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        cours = enseignant.cours
        charge = enseignant.charge
        service = 0
        filout.write("service de " + enseignant.prenom + " " + nom_enseignant + " :" + "\n")
        for j in range(len(cours)):
            duree = cours[j].duree
            nseances = cours[j].nseances
            groupes = cours[j].groupes
            enseignement = cours[j].enseignement
            niveau = enseignement.niveau
            semestre = int(enseignement.semestre)
            code = enseignement.code
            if (isinstance(code, (int, float))):
                code = "Gal"            
            titre = enseignement.titre
            TD_CM = coefTDCM(cours[j].type)
            hetd = duree * nseances * groupes * TD_CM
            filout.write(niveau + " "+ "S"+str(semestre) + " "+ code + " "+ titre + " : "  + str(hetd) + " "+ "hetd" + "\n")
            #filout.write(niveau + " "+ "S"+str(semestre) +  " "+ titre + " : "  + str(hetd) + " "+ "hetd" + "\n")
            service += hetd
        for j in range(len(charge)):
            hetd = charge[j].htd
            titre = charge[j].titre
            #filout.write(titre + " : "  + hetd + "hetd")
            filout.write(titre + " : "  + str(hetd) + "hetd" + "\n")
            service += hetd
        filout.write ("total : " + str(service) + " "+ "hetd" + "\n" + "\n")

def coefTDCM(typ):
    if(typ=="TD"):
        coef = 1
    elif(typ=="CM"):
        coef = 1.5 
    else:
        coef = 0 
    return coef
                

#with open("service_Pottier.txt", "w") as filout:
#    service_print(Enseignants, "Pottier", filout)

# %%
def services_print (LEnseignants, filename):
    with open(filename, "w") as filout:
        liste_enseignants = noms_enseignants(Enseignants)
        liste_enseignants_tri = sorted(noms_enseignants(Enseignants))
        # les enseignants Musique
        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #print (enseignant.statut)
            #service(Enseignants, liste_enseignants_tri[i])
            if (not (isinstance(enseignant.statut, (int, float)))):
                if ("Musique" in enseignant.statut):
                    service_print(Enseignants, liste_enseignants_tri[i], filout)
       # les autres enseignants
        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #service(Enseignants, liste_enseignants_tri[i])
            if (not (isinstance(enseignant.statut, (int, float)))):
                if (not "Musique" in enseignant.statut):
                    service_print(Enseignants, liste_enseignants_tri[i], filout)
                
services_print(Enseignants, "services.txt")

# %%
def service_det_print(LEnseignants, nom_enseignant, filout):
        liste_enseignants = noms_enseignants(LEnseignants)
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        cours = enseignant.cours
        charge = enseignant.charge
        service = 0
        hdebut = 0
        filout.write("** Service " + enseignant.prenom + " " + nom_enseignant + "\n"+ "\n")
        for j in range(len(cours)):
            duree = cours[j].duree
            nseances = cours[j].nseances
            groupes = cours[j].groupes
            salle = cours[j].salle
            jour = cours[j].jour
            duree = cours[j].duree
            rqs = cours[j].rqs
            enseignement = cours[j].enseignement
            niveau = enseignement.niveau
            semestre = int(enseignement.semestre)
            code = enseignement.code
            if (isinstance(code, (int, float))):
                code = "Gal"            
            titre = enseignement.titre
            TD_CM = coefTDCM(cours[j].type)
            hetd = duree * nseances * groupes * TD_CM
            filout.write("* " + niveau + " "+ "S"+str(semestre) + " "+ code + " "+ titre + " : "  + str(hetd) + " "+ "hetd" + "\n")
            service += hetd
            #filout.write(str(salle) + " "+ str(jour) + " " + str(hdebut) + " " + "durée = "+str(duree)+"h" +"\n")
            if (isinstance (cours[j].hdebut, datetime.time)):
                hdebut = cours[j].hdebut
                filout.write(str(salle) + " "+ str(jour) + " " + str(hdebut.hour) + 
                             "h"+str(hdebut.minute)  + " " + "durée = "+str(duree)+"h" +"\n")
            if (not (isinstance(rqs, (int, float)))): 
                filout.write("rqs : "+ rqs +"\n")
          
        for j in range(len(charge)):
            hetd = charge[j].htd
            titre = charge[j].titre
            rqs = charge[j].rqs
            filout.write("* " + titre + " : "  + str(hetd) + "hetd" + "\n")
            service += hetd
            if (not (isinstance(rqs, (int, float)))): 
                filout.write("rqs : "+ rqs +"\n")
        
        filout.write ("\n" + "TOTAL : " + str(service) + " "+ "hetd" + "\n" + "\n")


#with open("service_Pottier.txt", "w") as filout:
#    service_print(Enseignants, "Pottier", filout)

# %%
#file to write in

def services_details_print(LEnseignants, filename):    
    with open(filename, "w") as filout:
        liste_enseignants = noms_enseignants(Enseignants)
        liste_enseignants_tri = sorted(noms_enseignants(Enseignants))
        # les enseignants Musique
        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #print (enseignant.statut)
            #service(Enseignants, liste_enseignants_tri[i])
            if (not (isinstance(enseignant.statut, (int, float)))):
                if ("Musique" in enseignant.statut):
                    service_det_print(Enseignants, liste_enseignants_tri[i], filout)
       # les autres enseignants
        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #service(Enseignants, liste_enseignants_tri[i])
            if (not (isinstance(enseignant.statut, (int, float)))):
                if (not "Musique" in enseignant.statut):
                    service_det_print(Enseignants, liste_enseignants_tri[i], filout)
                
                
services_details_print(Enseignants, "services_details.txt")

# %%
def service_det_html(LEnseignants, nom_enseignant, filout):
        liste_enseignants = noms_enseignants(LEnseignants)
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        cours = enseignant.cours
        charge = enseignant.charge
        service = 0
        hdebut = 0
        filout.write("<h1> Service " + enseignant.prenom + " " + nom_enseignant + "</h1>\n")
        for j in range(len(cours)):
            duree = cours[j].duree
            nseances = cours[j].nseances
            groupes = cours[j].groupes
            salle = cours[j].salle
            jour = cours[j].jour
            duree = cours[j].duree
            rqs = cours[j].rqs
            enseignement = cours[j].enseignement
            niveau = enseignement.niveau
            semestre = int(enseignement.semestre)
            code = enseignement.code
            if (isinstance(code, (int, float))):
                code = "Gal"            
            titre = enseignement.titre
            TD_CM = coefTDCM(cours[j].type)
            hetd = duree * nseances * groupes * TD_CM
            filout.write("<h2>" + niveau + " "+ "S"+str(semestre) + " "+ code + " "+ titre + "</h2>\n")
            filout.write("<p>HETD : "  + str(hetd) + " hetd</p>")
            service += hetd
            #filout.write(str(salle) + " "+ str(jour) + " " + str(hdebut) + " " + "durée = "+str(duree)+"h" +"\n")
            if (isinstance (cours[j].hdebut, datetime.time)):
                hdebut = cours[j].hdebut
                filout.write("<p>salle "+str(salle) + " "+ str(jour) + " " + str(hdebut.hour) + 
                             "h"+str(hdebut.minute)  + " " + "durée = "+str(duree)+"h" + "</p>" + "\n")
            if (not (isinstance(rqs, (int, float)))): 
                filout.write("rqs : "+ rqs +"\n")
          
        for j in range(len(charge)):
            hetd = charge[j].htd
            titre = charge[j].titre
            rqs = charge[j].rqs
            filout.write("<h2>" + titre + "</h2>\n")
            filout.write("<p>HETD : "  + str(hetd) + " hetd</p>\n")
            service += hetd
            if (not (isinstance(rqs, (int, float)))): 
                filout.write("<p>rqs : "+ rqs +"</p>\n")
        
        filout.write ("<h3>TOTAL : " + str(service) + " "+ " hetd" + "</h3>\n")


#with open("service_Pottier.txt", "w") as filout:
#    service_print(Enseignants, "Pottier", filout)

# %%
#file to write in (html version)

def services_details_html(LEnseignants, filename):    
    with open(filename, "w") as filout:
        liste_enseignants = noms_enseignants(Enseignants)
        liste_enseignants_tri = sorted(noms_enseignants(Enseignants))
        # les enseignants Musique
        filout.write ("<!DOCTYPE html>\n")
        filout.write ("<html>\n")
        filout.write ("<head>\n")
        filout.write ("<title>Services 2021-22</title>\n")
        filout.write ("<meta charset=\"utf-8\" />\n")
        filout.write ("<link href=\"styles.css\" rel=\"stylesheet\" type=\"text/css\">\n")
        filout.write ("</head>\n")
        filout.write ("<body>\n")

        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #print (enseignant.statut)
            #service(Enseignants, liste_enseignants_tri[i])
            if (not (isinstance(enseignant.statut, (int, float)))):
                if ("Musique" in enseignant.statut):
                    service_det_html(Enseignants, liste_enseignants_tri[i], filout)
       # les autres enseignants
        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #service(Enseignants, liste_enseignants_tri[i])
            if (not (isinstance(enseignant.statut, (int, float)))):
                if (not "Musique" in enseignant.statut):
                    service_det_html(Enseignants, liste_enseignants_tri[i], filout)
            filout.write ("</body>\n")
            filout.write ("</html>")
        
                
services_details_html(Enseignants, "services_details2.html")

# %% [markdown]
# ## Planning (graphique)

# %%
       
def findSalle(code, Lsalles):
    res = 0
    for j in range (len(Lsalles)):
        if (code == Lsalles[j].code):
            res = 1
            break
    return res
    
def Lsalles(base):
    Lres = []
    salle = "nil"
    for j in range(base.shape[0]):
        site = base.site[1+j]
        code = base.salle[1+j]
        if not (isinstance(code, (int, float))):
            #print(code)
            salle = Salle(site, code)
            #print (findSalle(code , Lres))
            if not (findSalle(code , Lres))  :
                #print("kjkjkj")
                Lres.append (salle)
    return Lres

# %%
# liste des salles de cours utilisées

SallesDeCours = []   

SallesDeCours = Lsalles (X) 

SallesDeCours.sort(key=operator.attrgetter('site'), reverse=True)

for n in range(len(SallesDeCours)):
    print (SallesDeCours[n].site + "-" +SallesDeCours[n].code) 

#print (findSalle('A230' , SallesDeCours))
#print(SallesDeCours)
# Out:
# Tref-HR8
# Tref-J02
# Tref-J11
# Tref-E21
# Tref-SR7
# Tref-L104
# Papin-A230
# Papin-A201
# Papin-A202
# MDU-MDU

# %%
# faire un tableau html graphique
# on trie d'abord les enseignements pour les mettre chacun dans un semestre
# on trie ensuite les enseignements du semestre pour les mettre chacun dans un jour de la semaine
# on trie ensuite les enseigneemnts d'un jour pour les mettre chacun dans une salle
# on prend enfin une salle et un jour et on produit le <tr> correspondant en fonction de l'heure et de la durée

# %%
Enseignants[1].cours[1].hdebut
# Out:
# datetime.time(14, 45)

# %%
cours_Simpair = []
cours_Spair = []

for i in range (len(Enseignants)):
    for j in range (len(Enseignants[i].cours)):
        if (Enseignants[i].cours[j].enseignement.semestre % 2 == 1):
            if (isinstance (Enseignants[i].cours[j].hdebut, datetime.time)):
                cours_Simpair.append(Enseignants[i].cours[j])
                print (Enseignants[i].cours[j].hdebut)
                x = len(cours_Simpair)
                #print ("b", cours_Simpair[x-1].cours[j].hdebut)
                print ("b", cours_Simpair[x-1].hdebut)
       # elif (Enseignants[i].cours[j].enseignement.semestre % 2 == 0):
        #    cours_Spair.append(Enseignants[i].cours[j])
            
print ("---------------")            
            
for i in range (len(cours_impair)):
    print ((cours_impair[i].enseignement.semestre) , "-" , cours_impair[i].enseignant.nom , " ", (cours_impair[i].hdebut))
# Out:
# 08:30:00
# b 08:30:00
# 10:45:00
# b 10:45:00
# 08:30:00
# b 08:30:00
# 15:30:00
# b 15:30:00
# 13:30:00
# b 13:30:00
# 13:30:00
# b 13:30:00
# 13:30:00
# b 13:30:00
# 16:45:00
# b 16:45:00
# 14:45:00
# b 14:45:00
# 13:30:00
# b 13:30:00
# 15:00:00
# b 15:00:00
# 13:30:00
# b 13:30:00
# 15:00:00
# b 15:00:00
# 16:30:00
# b 16:30:00
# 15:45:00
# b 15:45:00
# 13:30:00
# b 13:30:00
# 10:30:00
# b 10:30:00
# 11:45:00
# b 11:45:00
# 08:00:00
# b 08:00:00
# 08:30:00
# b 08:30:00
# 15:30:00
# b 15:30:00
# 10:30:00
# b 10:30:00
# 14:00:00
# b 14:00:00
# 15:00:00
# b 15:00:00
# 16:30:00
# b 16:30:00
# 08:00:00
# b 08:00:00
# 09:00:00
# b 09:00:00
# 14:00:00
# b 14:00:00
# 10:30:00
# b 10:30:00
# 10:30:00
# b 10:30:00
# 13:00:00
# b 13:00:00
# 17:00:00
# b 17:00:00
# 09:30:00
# b 09:30:00
# 09:30:00
# b 09:30:00
# 13:30:00
# b 13:30:00
# 08:00:00
# b 08:00:00
# 13:00:00
# b 13:00:00
# 13:30:00
# b 13:30:00
# 08:00:00
# b 08:00:00
# 15:30:00
# b 15:30:00
# 15:30:00
# b 15:30:00
# 09:30:00
# b 09:30:00
# 09:30:00
# b 09:30:00
# 09:30:00
# b 09:30:00
# 08:00:00
# b 08:00:00
# 15:15:00
# b 15:15:00
# 15:00:00
# b 15:00:00
# 10:00:00
# b 10:00:00
# 13:00:00
# b 13:00:00
# 13:00:00
# b 13:00:00
# 13:00:00
# b 13:00:00
# 13:30:00
# b 13:30:00
# 11:00:00
# b 11:00:00
# 15:30:00
# b 15:30:00
# 14:00:00
# b 14:00:00
# 15:30:00
# b 15:30:00
# 13:00:00
# b 13:00:00
# 10:00:00
# b 10:00:00
# 09:00:00
# b 09:00:00
# 10:30:00
# b 10:30:00
# 11:30:00
# b 11:30:00
# 08:30:00
# b 08:30:00
# 14:00:00
# b 14:00:00
# 10:30:00
# b 10:30:00
# 08:00:00
# b 08:00:00
# 08:00:00
# b 08:00:00
# 08:00:00
# b 08:00:00
# 15:30:00
# b 15:30:00
# 08:00:00
# b 08:00:00
# 09:30:00
# b 09:30:00
# 10:00:00
# b 10:00:00
# 09:00:00
# b 09:00:00
# 09:00:00
# b 09:00:00
# 09:00:00
# b 09:00:00
# ---------------
# 1.0 - Pottier   0
# 5.0 - Pottier   0
# 5.0 - Pottier   0
# 1.0 - Pottier   0
# 1.0 - Pottier   0
# 1.0 - Pottier   0
# 1.0 - Pottier   0
# 3.0 - Pottier   0
# 3.0 - Pottier   0
# 3.0 - Pottier   0
# 1.0 - Pottier   0
# 1.0 - Olivo   0
# 1.0 - Olivo   0
# 1.0 - Obali   0
# 1.0 - Obali   0
# 1.0 - Clerc   0
# 1.0 - Clerc   0
# 5.0 - Clerc   0
# 1.0 - Fargeton   0
# 1.0 - Fargeton   0
# 1.0 - Fargeton   0
# 1.0 - Fargeton   0
# 3.0 - Fargeton   0
# 3.0 - Fargeton   0
# 5.0 - Fargeton   0
# 1.0 - Fargeton   0
# 1.0 - Lapalu   0
# 1.0 - Houles   0
# 1.0 - Houles   0
# 1.0 - Houles   0
# 1.0 - Houles   0
# 1.0 - Houles   0
# 3.0 - Houles   0
# 3.0 - Houles   0
# 3.0 - Houles   0
# 3.0 - Houles   0
# 5.0 - Houles   0
# 1.0 - Houles   0
# 1.0 - Houles   0
# 1.0 - Y   0
# 1.0 - Bertrand   0
# 1.0 - Bertrand   0
# 3.0 - Bertrand   0
# 1.0 - Petiet   0
# 1.0 - Damon-Guillot   0
# 3.0 - Damon-Guillot   0
# 1.0 - Damon-Guillot   0
# 1.0 - Damon-Guillot   0
# 1.0 - Damon-Guillot   0
# 1.0 - Damon-Guillot   0
# 1.0 - Damon-Guillot   0
# 1.0 - X   0
# 3.0 - Cailliez   0
# 3.0 - Cailliez   0
# 5.0 - Cailliez   0
# 1.0 - Cailliez   0
# 1.0 - Cailliez   0
# 1.0 - Cailliez   0
# 5.0 - Desmet   0
# 5.0 - Desmet   0
# 1.0 - Desmet   0
# 3.0 - Tracy   0
# 3.0 - Viallon   0
# 5.0 - Viallon   0
# 3.0 - Fuchs   0
# 3.0 - Fuchs   0
# 5.0 - Fuchs   0
# 5.0 - Fuchs   0
# 3.0 - Forment   0
# 5.0 - Bardot   0
# 5.0 - Terras   0
# 5.0 - Garde   0
# 5.0 - Garde   0
# 5.0 - Garde   0
# 1.0 - Waschbüsch   0
# 3.0 - Waschbüsch   0
# 3.0 - Waschbüsch   0
# 1.0 - Moussart   0
# 1.0 - Aliot   0
# 1.0 - Carinola   0
# 1.0 - Carinola   0
# 1.0 - Jacquelot   0
# 1.0 - Michon   0
# 1.0 - Michon   0
# 1.0 - Dalem   0

# %%
#len(cours_Simpair)
cours_Simpair[1].hdebl:u::::::::::t::::::(;§::)
# Out:
# 'J11'

# %%
cours_impair[1].hdebut
# Out:
# 0

# %%
cours_lundi_Simpair = []
cours_mardi_Simpair = []
cours_mercredi_Simpair = []
cours_jeudi_Simpair = []
cours_vendredi_Simpair = []

for j in range (len(cours_impair )):
    if (cours_Simpair[j].jour == "lundi"):
        cours_lundi_Simpair.append(cours_impair[j])
    elif (cours_Simpair[j].jour == "mardi"):
        cours_mardi_Simpair.append(cours_impair[j])
    elif (cours_Simpair[j].jour == "mercredi"):
        cours_mercredi_Simpair.append(cours_impair[j])
    elif (cours_Simpair[j].jour == "jeudi"):
        cours_jeudi_Simpair.append(cours_impair[j])
    elif (cours_Simpair[j].jour == "vendredi"):
        cours_vendredi_Simpair.append(cours_impair[j])
    
#for i in range (len(cours_lundi_Simpair)):
#    print (str(cours_lundi_Simpair[i].enseignement.semestre) + "-" + cours_lundi_Simpair[i].enseignant.nom)


#semestre1 = Semestre(coursS1)

# %%
SallesDeCours_Lundi = [] 
SallesDeCours_Mardi = [] 
SallesDeCours_Mercredi = [] 
SallesDeCours_Jeudi = [] 
SallesDeCours_Vendredi = [] 

for i in range (len(cours_lundi_Simpair )):
    for j in range (len (SallesDeCours)) :
        #print (cours_lundi_Simpair[i].salle)
        if (SallesDeCours[j].code == cours_lundi_Simpair[i].salle):
            SallesDeCours_Lundi.append(cours_lundi_Simpair[i])
            
for i in range (len(SallesDeCours_Lundi )): 
    print (SallesDeCours_Lundi[i].enseignant.nom, " " , SallesDeCours_Lundi[i].salle, " ",
           SallesDeCours_Lundi[i].hdebut.hour)
    #print ("durée : " , SallesDeCours_Lundi[i].duree )
            
##print (heure1.hour)
#print (heure1.minute)
    
#SallesDeCours

print("heure :" , str(Enseignants[1].cours[1].hdebut.hour)+"h"+str(Enseignants[1].cours[1].hdebut.minute))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-297-e9a9cb5e0dec> in <module>
#      13 for i in range (len(SallesDeCours_Lundi )):
#      14     print (SallesDeCours_Lundi[i].enseignant.nom, " " , SallesDeCours_Lundi[i].salle, " ",
# ---> 15            SallesDeCours_Lundi[i].hdebut.hour)
#      16     print ("durée : " , SallesDeCours_Lundi[i].duree )
#      17
#
# AttributeError: 'int' object has no attribute 'hour'

# %%
print (SallesDeCours_Lundi[3].salle)
# Out:
# J02

# %%
for i in range (len (cours_lundi_Simpair)) :
    print (cours_lundi_Simpair[i].salle + " " + cours_lundi_Simpair[i].enseignant.nom)
# Out:
# HR8 Obali
# HR8 Obali
# J02 Clerc
# J02 Clerc
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-261-4f7a6a9b3448> in <module>
#       1 for i in range (len (cours_lundi_Simpair)) :
# ----> 2     print (cours_lundi_Simpair[i].salle + " " + cours_lundi_Simpair[i].enseignant.nom)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
#for i in range (len (cours_impair)) :
#   print (cours_impair[i].salle + " " + cours_lundi_Simpair[i].enseignant.nom) 

print (cours_impair)
# Out:
# HR8 Pottier
# A201 Pottier
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-218-8ccdbbcf3ad2> in <module>
#       1 for i in range (len (cours_impair)) :
# ----> 2     print (cours_impair[i].salle + " " + cours_lundi_Simpair[i].enseignant.nom)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
